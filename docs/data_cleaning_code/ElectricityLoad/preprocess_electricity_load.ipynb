# %%
import pandas as pd
import numpy as np
import os

# %%
files = os.listdir()
df = pd.read_csv(files[0], delimiter = ';', low_memory = False)

# %%
def convert_to_float(value):
    try:
        return float(value.replace(',', '.'))
    except ValueError:
        # Handle non-numeric values here, if necessary
        return value

# %%
for column in df.columns[1:]:
    if df[column].dtype == 'object':
        df[column] = df[column].apply(convert_to_float)

# %%
df_filtered = df.loc[~(df.iloc[:,1] == 0.0)]

# %%
df_filtered.head()
# Out:
#                 Unnamed: 0    MT_001     MT_002     MT_003      MT_004  \
# 35040  2012-01-01 00:15:00  3.807107  22.759602  77.324066  136.178862
# 35041  2012-01-01 00:30:00  5.076142  22.759602  77.324066  136.178862
# 35042  2012-01-01 00:45:00  3.807107  22.759602  77.324066  140.243902
# 35043  2012-01-01 01:00:00  3.807107  22.759602  77.324066  140.243902
# 35044  2012-01-01 01:15:00  5.076142  22.048364  77.324066  146.341463
#
#           MT_005      MT_006    MT_007      MT_008     MT_009  ...  \
# 35040  70.731707  351.190476  9.609949  279.461279  75.174825  ...
# 35041  73.170732  354.166667  9.044658  279.461279  73.426573  ...
# 35042  69.512195  348.214286  8.479367  279.461279  75.174825  ...
# 35043  75.609756  339.285714  7.348785  279.461279  68.181818  ...
# 35044  73.170732  342.261905  6.783493  265.993266  69.930070  ...
#
#            MT_361   MT_362       MT_363       MT_364     MT_365     MT_366  \
# ...

# %%
df_filtered['Datetime'] = pd.to_datetime(df['Unnamed: 0'])
# Out:
# /var/folders/sw/dp504h291j9fp6lbnfw1pn_c0000gn/T/ipykernel_1729/3915458057.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_filtered['Datetime'] = pd.to_datetime(df['Unnamed: 0'])
# /var/folders/sw/dp504h291j9fp6lbnfw1pn_c0000gn/T/ipykernel_1729/3915458057.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Datetime'] = pd.to_datetime(df['Unnamed: 0'])

# %%
df_filtered.head()
# Out:
#                 Unnamed: 0    MT_001     MT_002     MT_003      MT_004  \
# 35040  2012-01-01 00:15:00  3.807107  22.759602  77.324066  136.178862
# 35041  2012-01-01 00:30:00  5.076142  22.759602  77.324066  136.178862
# 35042  2012-01-01 00:45:00  3.807107  22.759602  77.324066  140.243902
# 35043  2012-01-01 01:00:00  3.807107  22.759602  77.324066  140.243902
# 35044  2012-01-01 01:15:00  5.076142  22.048364  77.324066  146.341463
#
#           MT_005      MT_006    MT_007      MT_008     MT_009  ...  \
# 35040  70.731707  351.190476  9.609949  279.461279  75.174825  ...
# 35041  73.170732  354.166667  9.044658  279.461279  73.426573  ...
# 35042  69.512195  348.214286  8.479367  279.461279  75.174825  ...
# 35043  75.609756  339.285714  7.348785  279.461279  68.181818  ...
# 35044  73.170732  342.261905  6.783493  265.993266  69.930070  ...
#
#             MT_364     MT_365     MT_366      MT_367     MT_368      MT_369  \
# ...

# %%
df_filtered['Date'] = datetime.dt.date
# Out:
# /var/folders/sw/dp504h291j9fp6lbnfw1pn_c0000gn/T/ipykernel_1729/3177587991.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Date'] = datetime.dt.date

# %%
df_filtered.columns
# Out:
# Index(['Unnamed: 0', 'MT_001', 'MT_002', 'MT_003', 'MT_004', 'MT_005',
#        'MT_006', 'MT_007', 'MT_008', 'MT_009',
#        ...
#        'MT_364', 'MT_365', 'MT_366', 'MT_367', 'MT_368', 'MT_369', 'MT_370',
#        'Date', 'Time', 'Datetime'],
#       dtype='object', length=374)

# %%
df_filtered.drop(columns = ['Datetime', 'Unnamed: 0'], inplace = True)
# Out:
# /var/folders/sw/dp504h291j9fp6lbnfw1pn_c0000gn/T/ipykernel_1729/471389498.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop(columns = ['Datetime', 'Unnamed: 0'], inplace = True)

# %%
df_filtered.columns
# Out:
# Index(['MT_001', 'MT_002', 'MT_003', 'MT_004', 'MT_005', 'MT_006', 'MT_007',
#        'MT_008', 'MT_009', 'MT_010',
#        ...
#        'MT_363', 'MT_364', 'MT_365', 'MT_366', 'MT_367', 'MT_368', 'MT_369',
#        'MT_370', 'Date', 'Time'],
#       dtype='object', length=372)

# %%
columns = df_filtered.columns.to_list()

# %%
columns = columns[-2:] + columns[:-2]

# %%
df_filtered = df_filtered[columns]

# %%
df_filtered.head()
# Out:
#              Date      Time    MT_001     MT_002     MT_003      MT_004  \
# 35040  2012-01-01  00:15:00  3.807107  22.759602  77.324066  136.178862
# 35041  2012-01-01  00:30:00  5.076142  22.759602  77.324066  136.178862
# 35042  2012-01-01  00:45:00  3.807107  22.759602  77.324066  140.243902
# 35043  2012-01-01  01:00:00  3.807107  22.759602  77.324066  140.243902
# 35044  2012-01-01  01:15:00  5.076142  22.048364  77.324066  146.341463
#
#           MT_005      MT_006    MT_007      MT_008  ...      MT_361   MT_362  \
# 35040  70.731707  351.190476  9.609949  279.461279  ...  128.479657  28500.0
# 35041  73.170732  354.166667  9.044658  279.461279  ...  127.765882  26400.0
# 35042  69.512195  348.214286  8.479367  279.461279  ...  114.204140  25200.0
# 35043  75.609756  339.285714  7.348785  279.461279  ...  112.062812  23800.0
# 35044  73.170732  342.261905  6.783493  265.993266  ...  112.776588  23700.0
#
# ...

# %%
df_filtered.to_csv('data_cleaned.csv')
